# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
population = pd.read_csv("A:/Datasets/Annual_Population_Estimates_for_New_York_State_and_Counties__Beginning_1970.csv")

# %%
population.head()
# Out:
#    FIPS Code        Geography  Year                    Program Type  \
# 0      36000   New York State  2019  Postcensal Population Estimate
# 1      36001    Albany County  2019  Postcensal Population Estimate
# 2      36003  Allegany County  2019  Postcensal Population Estimate
# 3      36005     Bronx County  2019  Postcensal Population Estimate
# 4      36007    Broome County  2019  Postcensal Population Estimate
#
#    Population
# 0    19453561
# 1      305506
# 2       46091
# 3     1418207
# 4      190488

# %%
population = population.rename(columns={'Program Type':'ProgramType','FIPS Code':'Code'})
population
# Out:
#        Code           Geography  Year                      ProgramType  \
# 0     36000      New York State  2019   Postcensal Population Estimate
# 1     36001       Albany County  2019   Postcensal Population Estimate
# 2     36003     Allegany County  2019   Postcensal Population Estimate
# 3     36005        Bronx County  2019   Postcensal Population Estimate
# 4     36007       Broome County  2019   Postcensal Population Estimate
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 0       19453561
# 1         305506
# 2          46091
# 3        1418207
# 4         190488
# ...

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3465 entries, 0 to 3464
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Code         3465 non-null   int64
#  1   Geography    3465 non-null   object
#  2   Year         3465 non-null   int64
#  3   ProgramType  3465 non-null   object
#  4   Population   3465 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 135.5+ KB

# %%
population.iloc[3080]
# Out:
# Code                                     36111
# Geography                        Ulster County
# Year                                      1975
# ProgramType    Intercensal Population Estimate
# Population                              156025
# Name: 3080, dtype: object

# %%
population.sort_values(by=['Code'],ascending=[True])
population
# Out:
#        Code           Geography  Year                      ProgramType  \
# 0     36000      New York State  2019   Postcensal Population Estimate
# 1     36001       Albany County  2019   Postcensal Population Estimate
# 2     36003     Allegany County  2019   Postcensal Population Estimate
# 3     36005        Bronx County  2019   Postcensal Population Estimate
# 4     36007       Broome County  2019   Postcensal Population Estimate
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 0       19453561
# 1         305506
# 2          46091
# 3        1418207
# 4         190488
# ...

# %%
pd.options.display.max_rows=60

# %%
population
# Out:
#        Code           Geography  Year                      ProgramType  \
# 0     36000      New York State  2019   Postcensal Population Estimate
# 1     36001       Albany County  2019   Postcensal Population Estimate
# 2     36003     Allegany County  2019   Postcensal Population Estimate
# 3     36005        Bronx County  2019   Postcensal Population Estimate
# 4     36007       Broome County  2019   Postcensal Population Estimate
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 0       19453561
# 1         305506
# 2          46091
# 3        1418207
# 4         190488
# ...

# %%
pd.reset_option('display.max_rows')

# %%
population['ProgramType'].describe()
# Out:
# count                                3465
# unique                                  3
# top       Intercensal Population Estimate
# freq                                 2520
# Name: ProgramType, dtype: object

# %%
population.ProgramType.unique()
# Out:
# array(['Postcensal Population Estimate', 'Census Base Population',
#        'Intercensal Population Estimate'], dtype=object)

# %%
missing2 = population.ProgramType.value_counts()['Postcensal Population Estimate']
print(missing2)
# Out:
# 630

# %%
missing1 = population.ProgramType.value_counts()['Census Base Population']
print(missing1)
# Out:
# 315

# %%
missing3 = population.ProgramType.value_counts()['Intercensal Population Estimate']
print(missing3)
# Out:
# 2520

# %%
duplicates= population[population.duplicated(subset=['Code','Year'])]
duplicates
# Out:
#        Code           Geography  Year                      ProgramType  \
# 630   36000      New York State  2010           Census Base Population
# 631   36001       Albany County  2010           Census Base Population
# 632   36003     Allegany County  2010           Census Base Population
# 633   36005        Bronx County  2010           Census Base Population
# 634   36007       Broome County  2010           Census Base Population
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 630     19378144
# 631       304208
# 632        48923
# 633      1384580
# 634       200675
# ...

# %%
duplicates.sort_values(by=['Code'],ascending=[True])
duplicates
# Out:
#        Code           Geography  Year                      ProgramType  \
# 630   36000      New York State  2010           Census Base Population
# 631   36001       Albany County  2010           Census Base Population
# 632   36003     Allegany County  2010           Census Base Population
# 633   36005        Bronx County  2010           Census Base Population
# 634   36007       Broome County  2010           Census Base Population
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 630     19378144
# 631       304208
# 632        48923
# 633      1384580
# 634       200675
# ...

# %%
duplicates.loc[duplicates.Geography=='New York State']
# Out:
#        Code       Geography  Year                      ProgramType  Population
# 630   36000  New York State  2010           Census Base Population    19378144
# 1323  36000  New York State  2000  Intercensal Population Estimate    19001780
# 2016  36000  New York State  1990  Intercensal Population Estimate    18020784
# 2709  36000  New York State  1980  Intercensal Population Estimate    17566376
# 3402  36000  New York State  1970  Intercensal Population Estimate    18266034

# %%
population.loc[population.Geography=='New York State']
# Out:
#        Code       Geography  Year                      ProgramType  Population
# 0     36000  New York State  2019   Postcensal Population Estimate    19453561
# 63    36000  New York State  2018   Postcensal Population Estimate    19530351
# 126   36000  New York State  2017   Postcensal Population Estimate    19589572
# 189   36000  New York State  2016   Postcensal Population Estimate    19633428
# 252   36000  New York State  2015   Postcensal Population Estimate    19654666
# 315   36000  New York State  2014   Postcensal Population Estimate    19651049
# 378   36000  New York State  2013   Postcensal Population Estimate    19624447
# 441   36000  New York State  2012   Postcensal Population Estimate    19572932
# 504   36000  New York State  2011   Postcensal Population Estimate    19499241
# 567   36000  New York State  2010   Postcensal Population Estimate    19399878
# 630   36000  New York State  2010           Census Base Population    19378144
# ...

# %%
population=population.drop_duplicates(subset=['Code','Year'], keep='last')

# %%
population
# Out:
#        Code           Geography  Year                      ProgramType  \
# 0     36000      New York State  2019   Postcensal Population Estimate
# 1     36001       Albany County  2019   Postcensal Population Estimate
# 2     36003     Allegany County  2019   Postcensal Population Estimate
# 3     36005        Bronx County  2019   Postcensal Population Estimate
# 4     36007       Broome County  2019   Postcensal Population Estimate
# ...     ...                 ...   ...                              ...
# 3460  36115   Washington County  1970  Intercensal Population Estimate
# 3461  36117        Wayne County  1970  Intercensal Population Estimate
# 3462  36119  Westchester County  1970  Intercensal Population Estimate
# 3463  36121      Wyoming County  1970  Intercensal Population Estimate
# 3464  36123        Yates County  1970  Intercensal Population Estimate
#
#       Population
# 0       19453561
# 1         305506
# 2          46091
# 3        1418207
# 4         190488
# ...

# %%
sorted_population= population.sort_values(by=['Geography','Year'], ascending='True')
sorted_population
# Out:
#        Code      Geography  Year                      ProgramType  Population
# 3403  36001  Albany County  1970  Intercensal Population Estimate      287114
# 3277  36001  Albany County  1971  Intercensal Population Estimate      288615
# 3214  36001  Albany County  1972  Intercensal Population Estimate      290302
# 3151  36001  Albany County  1973  Intercensal Population Estimate      289754
# 3088  36001  Albany County  1974  Intercensal Population Estimate      289148
# ...     ...            ...   ...                              ...         ...
# 314   36123   Yates County  2015   Postcensal Population Estimate       25128
# 251   36123   Yates County  2016   Postcensal Population Estimate       25059
# 188   36123   Yates County  2017   Postcensal Population Estimate       25002
# 125   36123   Yates County  2018   Postcensal Population Estimate       24951
# 62    36123   Yates County  2019   Postcensal Population Estimate       24913
#
# [3150 rows x 5 columns]

# %%
pivoted_population=population.pivot(index=['Geography','Code'],columns='Year',values='Population')
pivoted_population
# Out:
# Year                         1970     1971     1972     1973     1974  \
# Geography          Code
# Albany County      36001   287114   288615   290302   289754   289148
# Allegany County    36003    46782    48062    49963    50255    50539
# Bronx County       36005  1472841  1477414  1472517  1418905  1381621
# Broome County      36007   222065   223050   219760   219717   218031
# Cattaraugus County 36009    82176    84217    86193    84385    83950
# ...                           ...      ...      ...      ...      ...
# Washington County  36115    52938    53776    54547    54515    53896
# Wayne County       36117    79703    80919    82155    82318    83140
# Westchester County 36119   894227   893523   893625   886576   874617
# Wyoming County     36121    38000    39263    37966    38457    38885
# Yates County       36123    19978    20547    20539    20528    20431
#
# Year                         1975     1976     1977     1978     1979  ...  \
# ...

# %%
#sum_of_cols=pivoted_population.sum(axis=0)
#sum_of_cols

# %%
#t_sum_of_cols=sum_of_cols.transpose()
#t_sum_of_cols

# %%
# var1=pd.Series([sum_of_cols],index=['NYC'])
# var1
# srs = var1.to_frame()
# df = pivoted_population.append(srs)
# df

# %%
# new_population=pivoted_population.append(var1)
# new_population

# %%
abc = population.ProgramType.value_counts()
abc
pop=population.ProgramType.unique()
pop
# Out:
# array(['Postcensal Population Estimate', 'Census Base Population',
#        'Intercensal Population Estimate'], dtype=object)

# %%
ypos=np.arange(len(pop))
ypos
# Out:
# array([0, 1, 2])

# %%
plt.xticks(ypos,pop, rotation=45)
plt.bar(ypos,abc)
# Out:
# <BarContainer object of 3 artists>

# %%
x=pivoted_population.iloc[57,:]
x
# Out:
# Year
# 1970    49704
# 1971    50893
# 1972    51372
# 1973    51843
# 1974    52845
# 1975    53653
# 1976    53617
# 1977    54471
# 1978    54824
# 1979    55103
# 1980    54989
# 1981    55255
# 1982    55031
# 1983    55136
# 1984    55189
# 1985    55491
# 1986    55656
# 1987    56569
# 1988    57369
# 1989    58197
# 1990    59520
# 1991    60166
# 1992    60808
# 1993    61670
# 1994    61923
# 1995    62271
# 1996    62337
# 1997    62460
# 1998    62585
# 1999    63031
# 2000    63273
# 2001    63406
# 2002    63774
# 2003    64323
# 2004    64576
# 2005    65206
# 2006    65554
# 2007    65740
# 2008    65848
# 2009    65694
# 2010    65692
# 2011    65736
# 2012    65417
# 2013    65083
# 2014    64866
# 2015    64420
# 2016    64438
# 2017    64365
# 2018    64215
# 2019    63944
# Name: (Warren County, 36113), dtype: int64

# %%
plt.plot(x)

# %%
pivoted_population.to_csv('pivoted_popuation.csv')
