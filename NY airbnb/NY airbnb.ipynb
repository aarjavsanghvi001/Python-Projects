# %%
import pandas as pd
import seaborn as sns

# %%
ds=pd.read_csv('A:/Datasets/AB_NYC_2019.csv')
ds
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
ds.id.unique().shape
# Out:
# (48895,)

# %%
ds.host_id.unique().shape
# Out:
# (37457,)

# %%
ds.name.unique().shape
# Out:
# (47906,)

# %%
ds.neighbourhood_group.value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
ds.neighbourhood.unique().shape
# Out:
# (221,)

# %%
ds.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
ds.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
ds[ds.name.isnull()]
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 2854    1615764  NaN   6676776     Peter           Manhattan
# 3703    2232600  NaN  11395220      Anna           Manhattan
# 5775    4209595  NaN  20700823     Jesse           Manhattan
# 5975    4370230  NaN  22686810   Michaël           Manhattan
# 6269    4581788  NaN  21600904     Lucie            Brooklyn
# 6567    4756856  NaN   1832442  Carolina            Brooklyn
# 6605    4774658  NaN  24625694      Josh           Manhattan
# 8841    6782407  NaN  31147528  Huei-Yin            Brooklyn
# 11963   9325951  NaN  33377685  Jonathan           Manhattan
# 12824   9787590  NaN  50448556    Miguel           Manhattan
# 13059   9885866  NaN  37306329  Juliette           Manhattan
# 13401  10052289  NaN  49522403   Vanessa            Brooklyn
# 15819  12797684  NaN  69715276       Yan           Manhattan
# 16071  12988898  NaN  71552588    Andrea               Bronx
# ...

# %%
ds=ds.fillna({'name':'xyz','host_name':'xyz'})
ds
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
ds.loc[ds['id'] == 1615764]
# Out:
#            id name  host_id host_name neighbourhood_group      neighbourhood  \
# 2854  1615764  xyz  6676776     Peter           Manhattan  Battery Park City
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 2854  40.71239   -74.0162  Entire home/apt    400            1000
#
#       number_of_reviews last_review  reviews_per_month  \
# 2854                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 2854                               1               362

# %%
ds.loc[ds['host_id'] == 2787]
# Out:
#              id                                               name  host_id  \
# 0          2539                 Clean & quiet apt home by the park     2787
# 10372   7937553  Riomaggiore Room. Queen Bedroom in Bklyn Townh...     2787
# 13583  10160215                               Torre del Lago Room.     2787
# 13688  10267242  Cinque Terre Room.  Clean and Quiet Queen Bedroom     2787
# 13963  10593675  La Spezia room.  Clean, quiet and comfortable bed     2787
# 21556  17263207   Brooklyn home.  Comfort and clean. Liguria room.     2787
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0          John            Brooklyn    Kensington  40.64749  -73.97237
# 10372      John            Brooklyn   Bensonhurst  40.60951  -73.97622
# 13583      John            Brooklyn     Gravesend  40.60755  -73.97410
# 13688      John            Brooklyn     Gravesend  40.60810  -73.97541
# 13963      John            Brooklyn   Bensonhurst  40.60951  -73.97642
# ...

# %%
sorted_ds=ds.sort_values(by=['neighbourhood_group','neighbourhood','room_type','price'],ascending=True)
sorted_ds
# Out:
#              id                                               name    host_id  \
# 1666     755528                 PRIVATE BATH/TONS OF SUNLIGHT/SAFE    3684360
# 37564  29800915     Entire floor (private entrance) w/ 1 BR in NYC  224206042
# 42958  33363084  E community that is commercially (Website hidd...  242175033
# 27879  21830694                        A Piece of mind in the city   57882444
# 34470  27343189                             Jay's Studio Apartment  204036615
# ...         ...                                                ...        ...
# 23827  19236716                                   a beautiful home  134672751
# 23449  18993379  Home &Garden: lots local+fast 2 Manhattan/Broo...  132266502
# 29214  22420304           Nice bunkbed room with private bathroom!  164164069
# 34161  27088022     Bright, Brand NEW, and Spacious, Gorgeous Home  115827173
# 3049    1798271                      Spacious center hall colonial    9430973
#
# ...

# %%
sns.countplot(ds['neighbourhood_group'])
# Out:
# c:\python\python3.9.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='count'>

# %%
sns.countplot(x='neighbourhood', data=ds[ds.neighbourhood_group=='Bronx'])
# Out:
# <AxesSubplot:xlabel='neighbourhood', ylabel='count'>

# %%
sns.countplot(ds['room_type'])
# Out:
# c:\python\python3.9.4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='room_type', ylabel='count'>

# %%
bins=[0,5,10,15,20,25]
ds['countbin']=pd.cut(ds['calculated_host_listings_count'],bins)
plt=sns.countplot(data=ds,x='countbin')

# %%
ds
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
ds.sort_values(by=['calculated_host_listings_count'],ascending=False)
# Out:
#              id                                               name    host_id  \
# 39773  30937596         Sonder | 11th Ave | Contemporary 1BR + Gym  219517861
# 41463  32240788      Sonder | Stock Exchange | Serene 2BR + Lounge  219517861
# 41469  32240966       Sonder | Stock Exchange | Sleek 3BR + Lounge  219517861
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 41468  32240933     Sonder | Stock Exchange | Lively 1BR + Kitchen  219517861
# ...         ...                                                ...        ...
# 18593  14694447                                         near metro   91292951
# 18594  14694588           Spacious Studio Room in Flushing, Queens   91381742
# 18595  14695540      Private Suite · Sparkling Clean · Memory Foam   12061634
# 18596  14696215                       Entire 1 Bedroom in Gramercy   91393670
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %%
pivoted_ds=ds.pivot_table(index=['neighbourhood_group'])
pivoted_ds
# Out:
#                      availability_365  calculated_host_listings_count  \
# neighbourhood_group
# Bronx                      165.758937                        2.233731
# Brooklyn                   100.232292                        2.284371
# Manhattan                  111.979410                       12.791330
# Queens                     144.451818                        4.060184
# Staten Island              199.678284                        2.319035
#
#                           host_id            id   latitude  longitude  \
# neighbourhood_group
# Bronx                1.056099e+08  2.273492e+07  40.848305 -73.884552
# Brooklyn             5.671526e+07  1.825685e+07  40.685036 -73.951190
# Manhattan            6.783062e+07  1.877494e+07  40.765062 -73.974607
# Queens               9.615680e+07  2.175500e+07  40.731531 -73.872775
# Staten Island        9.853360e+07  2.159747e+07  40.610225 -74.105805
#
#                      minimum_nights  number_of_reviews       price  \
# ...

# %%
dpivoted_ds=pivoted_ds.drop(columns=['host_id','id','latitude','longitude'])
dpivoted_ds
# Out:
#                      availability_365  calculated_host_listings_count  \
# neighbourhood_group
# Bronx                      165.758937                        2.233731
# Brooklyn                   100.232292                        2.284371
# Manhattan                  111.979410                       12.791330
# Queens                     144.451818                        4.060184
# Staten Island              199.678284                        2.319035
#
#                      minimum_nights  number_of_reviews       price  \
# neighbourhood_group
# Bronx                      4.560953          26.004583   87.496792
# Brooklyn                   6.056556          24.202845  124.383207
# Manhattan                  8.579151          20.985596  196.875814
# Queens                     5.181433          27.700318   99.517649
# Staten Island              4.831099          30.941019  114.812332
#
#                      reviews_per_month
# neighbourhood_group
# ...

# %%
tdpivoted_ds=dpivoted_ds.transpose()
tdpivoted_ds
# Out:
# neighbourhood_group                  Bronx    Brooklyn   Manhattan  \
# availability_365                165.758937  100.232292  111.979410
# calculated_host_listings_count    2.233731    2.284371   12.791330
# minimum_nights                    4.560953    6.056556    8.579151
# number_of_reviews                26.004583   24.202845   20.985596
# price                            87.496792  124.383207  196.875814
# reviews_per_month                 1.837831    1.283212    1.272131
#
# neighbourhood_group                 Queens  Staten Island
# availability_365                144.451818     199.678284
# calculated_host_listings_count    4.060184       2.319035
# minimum_nights                    5.181433       4.831099
# number_of_reviews                27.700318      30.941019
# price                            99.517649     114.812332
# reviews_per_month                 1.941200       1.872580

# %%
ds.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# countbin                           2065
# dtype: int64

# %%
ds.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
ds=ds.drop(columns=['countbin'])
ds
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
ds.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
cor=ds.corr()
cor
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.588290 -0.003125   0.090908
# host_id                         0.588290  1.000000  0.020224   0.127055
# latitude                       -0.003125  0.020224  1.000000   0.084788
# longitude                       0.090908  0.127055  0.084788   1.000000
# price                           0.010619  0.015309  0.033939  -0.150019
# minimum_nights                 -0.013224 -0.017364  0.024869  -0.062747
# number_of_reviews              -0.319760 -0.140106 -0.015389   0.059094
# reviews_per_month               0.291828  0.296417 -0.010142   0.145948
# calculated_host_listings_count  0.133272  0.154950  0.019517  -0.114713
# availability_365                0.085468  0.203492 -0.010983   0.082731
#
#                                    price  minimum_nights  number_of_reviews  \
# id                              0.010619       -0.013224          -0.319760
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(8,6))
sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
ds['reviews_per_month'].describe()
# Out:
# count    38843.000000
# mean         1.373221
# std          1.680442
# min          0.010000
# 25%          0.190000
# 50%          0.720000
# 75%          2.020000
# max         58.500000
# Name: reviews_per_month, dtype: float64

# %%
ds['reviews_per_month']=ds['reviews_per_month'].fillna(1)

# %%
ds.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64
